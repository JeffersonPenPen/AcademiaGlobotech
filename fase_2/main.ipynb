# %%
from analise.sistema import SistemaAnaliseEngajamento
#Classe principal que gerencia os relatórios em sistema.py
import os #Para verificar csv

def exibir_menu(): #Menu para Processamento de Dados e Seleção de Relatórios
    print("\n--- MENU PRINCIPAL ---")
    print("1. Processar arquivo CSV")
    print("2. Gerar Relatório de Engajamento por Conteúdo")
    print("3. Gerar Relatório de Atividade de Usuários")
    print("4. Top Conteúdos por Tempo Total Consumido")
    print("0. Sair")
    return input("Escolha uma opção: ")

"""
Menu simples a partir de While/True para organizar o acesso
aos relatórios solicitados na diretriz do projeto.
'O main.py deve instanciar SistemaAnaliseEngajamento,
carregar os dados e apresentar as métricas.'
"""

sistema = SistemaAnaliseEngajamento()

caminho_csv = "interacoes_globo.csv"
"""
Pode ser ampliado futuramente para acessar um arquivo específico
com o endereço do csv e assim não ficar preso a apenas interacoes_globo.csv.
"""
dados_processados = False
#Processamento será inicializado pelo usuário no menu.

print("\n\nFase 2: Análise de Engajamento de Mídias Globo com Orientação a Objetos\n")

while True:
    opcao = exibir_menu()

    if opcao == "1":
        if os.path.exists(caminho_csv):
            sistema.processar_interacoes_do_csv(caminho_csv)
            dados_processados = True
            print("\nDados do arquivo CSV processados.")
        else:
            print(f"Arquivo CSV não encontrado: {caminho_csv}")

    elif opcao == "2":
        if dados_processados:
            sistema.gerar_relatorio_engajamento_conteudos() #Em sistema.py
        else:
            print("Primeiro processe o arquivo CSV (Opção 1).")

    elif opcao == "3":
        if dados_processados:
            sistema.gerar_relatorio_atividade_usuarios() #Em sistema.py
        else:
            print("Primeiro processe o arquivo CSV (Opção 1).")

    elif opcao == "4":
        if dados_processados:
            sistema.gerar_relatorio_top_conteudos_consumidos(5) #Em sistema.py
        else:
            print("Primeiro processe o arquivo CSV (Opção 1).")

    elif opcao == "0":
        print("Encerrando o programa.")
        break
    else:
        print("Opção inválida. Tente novamente.")
# Out:
# Fase 2: Análise de Engajamento de Mídias Globo com Orientação a Objetos
#
#
# --- MENU PRINCIPAL ---
# 1. Processar arquivo CSV
# 2. Gerar Relatório de Engajamento por Conteúdo
# 3. Gerar Relatório de Atividade de Usuários
# 4. Top Conteúdos por Tempo Total Consumido
# 0. Sair
# Escolha uma opção:  1
# Dados do arquivo CSV processados.
#
# --- MENU PRINCIPAL ---
# 1. Processar arquivo CSV
# 2. Gerar Relatório de Engajamento por Conteúdo
# 3. Gerar Relatório de Atividade de Usuários
# 4. Top Conteúdos por Tempo Total Consumido
# 0. Sair
# Escolha uma opção:  2
# -> -> RESULTADOS DE ENGAJAMENTO DE CONTEÚDOS <- <-
#
# ID: 1 - Jornal Nacional
# Total de interações: 0
# Interações por tipo:
#              view_start: 10
# Tempo total assistido: 18120 segundos ou 5:02:00
# Média de tempo assistido: 1812.00 segundos
#
#
#
# ID: 2 - Novela Renascer
# Total de interações: 4
# Interações por tipo:
#              view_start: 6
#              like: 1
#              comment: 1
#              share: 2
# Tempo total assistido: 16290 segundos ou 4:31:30
# Média de tempo assistido: 2715.00 segundos
# Quantidade de comentários: 1
# Comentário 1: Que capítulo emocionante!
#
#
#
# ID: 3 - Podcast Papo de Segunda
# Total de interações: 14
# Interações por tipo:
#              view_start: 7
#              comment: 9
#              share: 3
#              like: 2
# Tempo total assistido: 24850 segundos ou 6:54:10
# Média de tempo assistido: 3550.00 segundos
# Quantidade de comentários: 9
# Comentário 1: Muito bom o tema de hoje!
# Comentário 2: Adorei a discussão! Concordo plenamente.
# Comentário 3: Debate necessário.
# Comentário 4: Esse tema me fez refletir muito.
# Comentário 5: Excelente ponto de vista.
# Comentário 6: Poderiam trazer o fulano para debater.
# Comentário 7: Assunto super relevante para os dias atuais.
# Comentário 8: Convidem mais especialistas no assunto.
# Comentário 9: Sempre com temas pertinentes.
#
#
#
# ID: 4 - Jogo do Brasileirão Série A
# Total de interações: 10
# Interações por tipo:
#              view_start: 8
#              comment: 7
#              share: 1
#              like: 2
# Tempo total assistido: 57630 segundos ou 16:00:30
# Média de tempo assistido: 7203.75 segundos
# Quantidade de comentários: 7
# Comentário 1: Que jogaço!
# Comentário 2: VAR polêmico de novo...
# Comentário 3: Resultado justo.
# Comentário 4: Juiz ladrão!
# Comentário 5: Meu time ganhou! Uhul!
# Comentário 6: Foi pênalti claro!
# Comentário 7: Esse técnico precisa ser demitido!
#
#
#
# ID: 5 - Mais Você
# Total de interações: 0
# Interações por tipo:
#              view_start: 5
# Tempo total assistido: 6070 segundos ou 1:41:10
# Média de tempo assistido: 1214.00 segundos
#
#
#
# ID: 6 - The Voice Brasil
# Total de interações: 15
# Interações por tipo:
#              view_start: 30
#              like: 9
#              share: 2
#              comment: 4
# Tempo total assistido: 95320 segundos ou 26:28:40
# Média de tempo assistido: 3177.33 segundos
# Quantidade de comentários: 4
# Comentário 1: Essa candidata é incrível!
# Comentário 2: Torcendo muito!
# Comentário 3: Melhor apresentação da noite!
# Comentário 4: Arrasou na performance!
#
#
#
# ID: 7 - Podcast GE Tabelando
# Total de interações: 19
# Interações por tipo:
#              view_start: 9
#              comment: 16
#              share: 1
#              like: 2
# Tempo total assistido: 21920 segundos ou 6:05:20
# Média de tempo assistido: 2435.56 segundos
# Quantidade de comentários: 16
# Comentário 1: Análise perfeita da rodada.
# Comentário 2: Faltou falar do meu time!
# Comentário 3: Melhor podcast de futebol
# Comentário 4: Concordo com a análise do comentarista X.
# Comentário 5: Finalmente uma análise imparcial!
# Comentário 6: Dicas valiosas pro Cartola!
# Comentário 7: Amo esse podcast! Não perco um.
# Comentário 8: Análise tática impecável.
# Comentário 9: Não concordo com a escalação ideal.
# Comentário 10: Esse podcast é essencial.
# Comentário 11: Informação de qualidade.
# Comentário 12: Os melhores comentaristas estão aqui.
# Comentário 13: Podcast indispensável para quem ama futebol.
# Comentário 14: Só verdades foram ditas.
# Comentário 15: Acompanho toda semana.
# Comentário 16: Melhor análise esportiva da internet.
#
#
#
# ID: 8 - Sessão da Tarde Clássicos
# Total de interações: 1
# Interações por tipo:
#              view_start: 5
#              like: 1
# Tempo total assistido: 27000 segundos ou 7:30:00
# Média de tempo assistido: 5400.00 segundos
#
#
#
# ID: 9 - Show da Virada
# Total de interações: 0
# Interações por tipo:
#              view_start: 2
# Tempo total assistido: 21650 segundos ou 6:00:50
# Média de tempo assistido: 10825.00 segundos
#
#
#
# ID: 10 - Documentário Amazônia Viva
# Total de interações: 2
# Interações por tipo:
#              view_start: 5
#              like: 1
#              share: 1
# Tempo total assistido: 16530 segundos ou 4:35:30
# Média de tempo assistido: 3306.00 segundos
#
#
#
# ID: 11 - Receitas da Ana Maria
# Total de interações: 0
# Interações por tipo:
#              view_start: 2
# Tempo total assistido: 1250 segundos ou 0:20:50
# Média de tempo assistido: 625.00 segundos
#
#
#
# ID: 12 - Futebol de Sabado
# Total de interações: 6
# Interações por tipo:
#              view_start: 7
#              comment: 5
#              like: 1
# Tempo total assistido: 49000 segundos ou 13:36:40
# Média de tempo assistido: 7000.00 segundos
# Quantidade de comentários: 5
# Comentário 1: Esse narrador é demais!
# Comentário 2: Gol anulado injustamente!
# Comentário 3: Esse time precisa melhorar muito.
# Comentário 4: Que golaço!!!
# Comentário 5: Que defesaça do goleiro!
#
#
#
# ID: 13 - Desenrola Brasil Podcast
# Total de interações: 4
# Interações por tipo:
#              view_start: 3
#              comment: 3
#              like: 1
# Tempo total assistido: 5400 segundos ou 1:30:00
# Média de tempo assistido: 1800.00 segundos
# Quantidade de comentários: 3
# Comentário 1: Ótimas dicas financeiras.
# Comentário 2: Aprendi muito!
# Comentário 3: Muito útil
#
#
#
# ID: 14 - Globo Repórter Especial
# Total de interações: 1
# Interações por tipo:
#              view_start: 4
#              share: 1
# Tempo total assistido: 14450 segundos ou 4:00:50
# Média de tempo assistido: 3612.50 segundos
#
#
#
# ID: 15 - Domingão com Huck
# Total de interações: 4
# Interações por tipo:
#              view_start: 4
#              like: 2
#              comment: 1
#              share: 1
# Tempo total assistido: 28820 segundos ou 8:00:20
# Média de tempo assistido: 7205.00 segundos
# Quantidade de comentários: 1
# Comentário 1: Que história emocionante!
#
#
#
#
# --- MENU PRINCIPAL ---
# 1. Processar arquivo CSV
# 2. Gerar Relatório de Engajamento por Conteúdo
# 3. Gerar Relatório de Atividade de Usuários
# 4. Top Conteúdos por Tempo Total Consumido
# 0. Sair
# Escolha uma opção:  3
# -> -> RESULTADOS DE ATIVIDADE DE USUÁRIOS <- <-
#
# Usuário (ID): 101
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1800 segundos ou 0:30:00
# Média de tempo assistido: 1800.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 102
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2700 segundos ou 0:45:00
# Média de tempo assistido: 2700.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 103
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 104
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Muito bom o tema de hoje!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 105
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 106
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 107
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Que jogaço!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 108
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1200 segundos ou 0:20:00
# Média de tempo assistido: 1200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 110
# Número de Interações: 2
# Contagem por tipo de interação:
#              view_start: 2
# Tempo total assistido: 6200 segundos ou 1:43:20
# Média de tempo assistido: 3100.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 2 interação(ões)
#
#
#
# Usuário (ID): 111
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 113
# Número de Interações: 2
# Contagem por tipo de interação:
#              view_start: 1
#              like: 1
# Tempo total assistido: 2400 segundos ou 0:40:00
# Média de tempo assistido: 2400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 2 interação(ões)
#
#
#
# Usuário (ID): 114
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Análise perfeita da rodada.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 115
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 116
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 5400 segundos ou 1:30:00
# Média de tempo assistido: 5400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 117
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 10800 segundos ou 3:00:00
# Média de tempo assistido: 10800.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 118
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3300 segundos ou 0:55:00
# Média de tempo assistido: 3300.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 119
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 120
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 600 segundos ou 0:10:00
# Média de tempo assistido: 600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Receitas Gshow: 1 interação(ões)
#
#
#
# Usuário (ID): 122
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7000 segundos ou 1:56:40
# Média de tempo assistido: 7000.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 123
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Esse narrador é demais!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 124
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1800 segundos ou 0:30:00
# Média de tempo assistido: 1800.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 125
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Ótimas dicas financeiras.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 126
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 127
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 128
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 129
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3100 segundos ou 0:51:40
# Média de tempo assistido: 3100.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 131
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 132
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1850 segundos ou 0:30:50
# Média de tempo assistido: 1850.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 133
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2750 segundos ou 0:45:50
# Média de tempo assistido: 2750.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 134
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Adorei a discussão! Concordo plenamente.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 135
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 136
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7250 segundos ou 2:00:50
# Média de tempo assistido: 7250.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 137
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: VAR polêmico de novo...
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 138
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1250 segundos ou 0:20:50
# Média de tempo assistido: 1250.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 139
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3500 segundos ou 0:58:20
# Média de tempo assistido: 3500.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 140
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 141
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3300 segundos ou 0:55:00
# Média de tempo assistido: 3300.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 142
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Faltou falar do meu time!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 143
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2450 segundos ou 0:40:50
# Média de tempo assistido: 2450.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 144
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 5450 segundos ou 1:30:50
# Média de tempo assistido: 5450.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 145
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 10850 segundos ou 3:00:50
# Média de tempo assistido: 10850.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 146
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 147
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 650 segundos ou 0:10:50
# Média de tempo assistido: 650.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Receitas Gshow: 1 interação(ões)
#
#
#
# Usuário (ID): 148
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Gol anulado injustamente!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 149
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 150
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3650 segundos ou 1:00:50
# Média de tempo assistido: 3650.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 151
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Que história emocionante!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 152
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2900 segundos ou 0:48:20
# Média de tempo assistido: 2900.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 154
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1750 segundos ou 0:29:10
# Média de tempo assistido: 1750.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 155
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 156
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3620 segundos ou 1:00:20
# Média de tempo assistido: 3620.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 157
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 159
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3050 segundos ou 0:50:50
# Média de tempo assistido: 3050.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 160
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Essa candidata é incrível!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 161
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2350 segundos ou 0:39:10
# Média de tempo assistido: 2350.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 162
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Melhor podcast de futebol
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 163
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 164
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3350 segundos ou 0:55:50
# Média de tempo assistido: 3350.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 165
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7050 segundos ou 1:57:30
# Média de tempo assistido: 7050.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 166
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1820 segundos ou 0:30:20
# Média de tempo assistido: 1820.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 167
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7220 segundos ou 2:00:20
# Média de tempo assistido: 7220.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 168
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3150 segundos ou 0:52:30
# Média de tempo assistido: 3150.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 169
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 170
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1810 segundos ou 0:30:10
# Média de tempo assistido: 1810.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 171
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2710 segundos ou 0:45:10
# Média de tempo assistido: 2710.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 172
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 173
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Resultado justo.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 174
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3400 segundos ou 0:56:40
# Média de tempo assistido: 3400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 176
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 177
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Concordo com a análise do comentarista X.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 179
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7100 segundos ou 1:58:20
# Média de tempo assistido: 7100.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 180
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 181
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2950 segundos ou 0:49:10
# Média de tempo assistido: 2950.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 182
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Torcendo muito!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 183
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1830 segundos ou 0:30:30
# Média de tempo assistido: 1830.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 184
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Que capítulo emocionante!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 185
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3580 segundos ou 0:59:40
# Média de tempo assistido: 3580.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 186
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7150 segundos ou 1:59:10
# Média de tempo assistido: 7150.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 187
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1220 segundos ou 0:20:20
# Média de tempo assistido: 1220.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 188
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3250 segundos ou 0:54:10
# Média de tempo assistido: 3250.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 189
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 190
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Finalmente uma análise imparcial!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 191
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 5350 segundos ou 1:29:10
# Média de tempo assistido: 5350.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 192
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3280 segundos ou 0:54:40
# Média de tempo assistido: 3280.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 193
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Esse time precisa melhorar muito.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 194
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1780 segundos ou 0:29:40
# Média de tempo assistido: 1780.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 195
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 196
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3020 segundos ou 0:50:20
# Média de tempo assistido: 3020.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 198
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1780 segundos ou 0:29:40
# Média de tempo assistido: 1780.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Canal Brasil: 1 interação(ões)
#
#
#
# Usuário (ID): 199
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2730 segundos ou 0:45:30
# Média de tempo assistido: 2730.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Viva: 1 interação(ões)
#
#
#
# Usuário (ID): 200
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Debate necessário.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Multishow: 1 interação(ões)
#
#
#
# Usuário (ID): 201
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7180 segundos ou 1:59:40
# Média de tempo assistido: 7180.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GNT Play: 1 interação(ões)
#
#
#
# Usuário (ID): 202
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3320 segundos ou 0:55:20
# Média de tempo assistido: 3320.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 203
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Dicas valiosas pro Cartola!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              App Cartola: 1 interação(ões)
#
#
#
# Usuário (ID): 204
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 205
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3120 segundos ou 0:52:00
# Média de tempo assistido: 3120.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 206
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 207
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2420 segundos ou 0:40:20
# Média de tempo assistido: 2420.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 208
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Amo esse podcast! Não perco um.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 209
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 210
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3550 segundos ou 0:59:10
# Média de tempo assistido: 3550.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 211
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Melhor apresentação da noite!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 212
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Juiz ladrão!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 213
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 6900 segundos ou 1:55:00
# Média de tempo assistido: 6900.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 214
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Que golaço!!!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 215
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3000 segundos ou 0:50:00
# Média de tempo assistido: 3000.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 216
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 217
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2500 segundos ou 0:41:40
# Média de tempo assistido: 2500.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 218
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Análise tática impecável.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 219
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3400 segundos ou 0:56:40
# Média de tempo assistido: 3400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 220
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Esse tema me fez refletir muito.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 221
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3200 segundos ou 0:53:20
# Média de tempo assistido: 3200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 223
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 224
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Meu time ganhou! Uhul!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 225
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 226
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Não concordo com a escalação ideal.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 227
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3100 segundos ou 0:51:40
# Média de tempo assistido: 3100.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 228
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1800 segundos ou 0:30:00
# Média de tempo assistido: 1800.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 229
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2700 segundos ou 0:45:00
# Média de tempo assistido: 2700.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 230
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 231
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Excelente ponto de vista.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 232
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 233
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1200 segundos ou 0:20:00
# Média de tempo assistido: 1200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 234
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3000 segundos ou 0:50:00
# Média de tempo assistido: 3000.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 235
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 236
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2400 segundos ou 0:40:00
# Média de tempo assistido: 2400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 237
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Esse podcast é essencial.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 238
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 5400 segundos ou 1:30:00
# Média de tempo assistido: 5400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 239
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3300 segundos ou 0:55:00
# Média de tempo assistido: 3300.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 241
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7000 segundos ou 1:56:40
# Média de tempo assistido: 7000.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 242
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Aprendi muito!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 243
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 244
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 245
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3100 segundos ou 0:51:40
# Média de tempo assistido: 3100.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 247
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1850 segundos ou 0:30:50
# Média de tempo assistido: 1850.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 248
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 249
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Poderiam trazer o fulano para debater.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 250
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 251
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3500 segundos ou 0:58:20
# Média de tempo assistido: 3500.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 252
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Informação de qualidade.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 253
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2980 segundos ou 0:49:40
# Média de tempo assistido: 2980.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 254
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 255
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2480 segundos ou 0:41:20
# Média de tempo assistido: 2480.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 256
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Os melhores comentaristas estão aqui.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 257
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 258
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 259
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Arrasou na performance!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 260
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Foi pênalti claro!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 261
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 6950 segundos ou 1:55:50
# Média de tempo assistido: 6950.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 262
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Que defesaça do goleiro!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 263
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3050 segundos ou 0:50:50
# Média de tempo assistido: 3050.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 264
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2520 segundos ou 0:42:00
# Média de tempo assistido: 2520.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 265
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Podcast indispensável para quem ama futebol.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Spotify: 1 interação(ões)
#
#
#
# Usuário (ID): 266
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3450 segundos ou 0:57:30
# Média de tempo assistido: 3450.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 267
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Assunto super relevante para os dias atuais.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 268
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3250 segundos ou 0:54:10
# Média de tempo assistido: 3250.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 270
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7250 segundos ou 2:00:50
# Média de tempo assistido: 7250.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 271
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Esse técnico precisa ser demitido!
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 272
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Só verdades foram ditas.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 273
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3150 segundos ou 0:52:30
# Média de tempo assistido: 3150.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 274
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1800 segundos ou 0:30:00
# Média de tempo assistido: 1800.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 275
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2700 segundos ou 0:45:00
# Média de tempo assistido: 2700.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 276
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 277
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Convidem mais especialistas no assunto.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 278
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 279
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1200 segundos ou 0:20:00
# Média de tempo assistido: 1200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 280
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3000 segundos ou 0:50:00
# Média de tempo assistido: 3000.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 281
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 282
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2400 segundos ou 0:40:00
# Média de tempo assistido: 2400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 283
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Acompanho toda semana.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 284
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 5400 segundos ou 1:30:00
# Média de tempo assistido: 5400.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 285
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3300 segundos ou 0:55:00
# Média de tempo assistido: 3300.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 287
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7000 segundos ou 1:56:40
# Média de tempo assistido: 7000.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Sportv Play: 1 interação(ões)
#
#
#
# Usuário (ID): 288
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Muito útil
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              G1: 1 interação(ões)
#
#
#
# Usuário (ID): 289
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3600 segundos ou 1:00:00
# Média de tempo assistido: 3600.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 290
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 7200 segundos ou 2:00:00
# Média de tempo assistido: 7200.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 291
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3100 segundos ou 0:51:40
# Média de tempo assistido: 3100.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 293
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 1850 segundos ou 0:30:50
# Média de tempo assistido: 1850.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 294
# Número de Interações: 1
# Contagem por tipo de interação:
#              share: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 295
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Sempre com temas pertinentes.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 296
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Premiere: 1 interação(ões)
#
#
#
# Usuário (ID): 297
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 3500 segundos ou 0:58:20
# Média de tempo assistido: 3500.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
# Usuário (ID): 298
# Número de Interações: 1
# Contagem por tipo de interação:
#              comment: 1
# Quantidade de comentários: 1
# Comentário 1: Melhor análise esportiva da internet.
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              GE Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 299
# Número de Interações: 1
# Contagem por tipo de interação:
#              view_start: 1
# Tempo total assistido: 2980 segundos ou 0:49:40
# Média de tempo assistido: 2980.00 segundos
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              TV Globo: 1 interação(ões)
#
#
#
# Usuário (ID): 300
# Número de Interações: 1
# Contagem por tipo de interação:
#              like: 1
# Conteúdos únicos consumidos: 1
# Top 3 Plataformas Mais Frequentes:
#              Globoplay: 1 interação(ões)
#
#
#
#
# --- MENU PRINCIPAL ---
# 1. Processar arquivo CSV
# 2. Gerar Relatório de Engajamento por Conteúdo
# 3. Gerar Relatório de Atividade de Usuários
# 4. Top Conteúdos por Tempo Total Consumido
# 0. Sair
# Escolha uma opção:  4
# -> -> TOP CONTEÚDOS POR TEMPO TOTAL CONSUMIDO <- <-
#
# 1o. The Voice Brasil (26:28:40 consumidos)
# 2o. Jogo do Brasileirão Série A (16:00:30 consumidos)
# 3o. Futebol de Sabado (13:36:40 consumidos)
# 4o. Domingão com Huck (8:00:20 consumidos)
# 5o. Sessão da Tarde Clássicos (7:30:00 consumidos)
#
# --- MENU PRINCIPAL ---
# 1. Processar arquivo CSV
# 2. Gerar Relatório de Engajamento por Conteúdo
# 3. Gerar Relatório de Atividade de Usuários
# 4. Top Conteúdos por Tempo Total Consumido
# 0. Sair
# Escolha uma opção:  0
# Encerrando o programa.
